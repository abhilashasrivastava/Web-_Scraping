# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
museums = """<div class="wild-life-tour">
                                 <h2>Museums in Lucknow</h2>
                                 <ul>
                                    <li>
                                       <a href="state-museum-lucknow.html" target="_blank"><img src="images/state-museum-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="state-museum-lucknow.html" target="_blank">
                                             <h3>State Muesum</h3>
                                          </a>                                          
                                       </div>
                                    </li>
                                    <li>
                                       <a href="motilal-nehru-children-museum-lucknow.html" target="_blank"><img src="images/motilal-nehru-children-museum-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="motilal-nehru-children-museum-lucknow.html" target="_blank">
                                             <h3>Motilal Nehru Children Museum</h3>
                                          </a>                                          
                                       </div>
                                    </li>
                                    <li>
                                       <a href="hussainabad-picture-gallery-lucknow.html" target="_blank"><img src="images/hussainabad-picture-gallery-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="hussainabad-picture-gallery-lucknow.html" target="_blank">
                                             <h3>Hussainabad Picture Gallery</h3>
                                          </a>
                                       </div>
                                    </li>
                                    <li>
                                       <a href="indira-gandhi-planetarium-lucknow.html" target="_blank"><img src="images/indira-gandhi-planetarium-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="indira-gandhi-planetarium-lucknow.html" target="_blank">
                                             <h3>Indira Gandhi Planetarium</h3>
                                          </a>
                                       </div>
                                    </li>
                                    <li>
                                       <a href="lok-kala-sangrahalaya-lucknow.html" target="_blank"><img src="images/lok-kala-sangrahalaya-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="lok-kala-sangrahalaya-lucknow.html" target="_blank">
                                             <h3>Lok Kala Sangrahalaya</h3>
                                          </a>
                                       </div>
                                    </li>
                                    <li>
                                       <a href="gandhi-museum-lucknow.html" target="_blank"><img src="images/gandhi-museum-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="gandhi-museum-lucknow.html" target="_blank">
                                             <h3>Gandhi Museum</h3>
                                          </a>
                                       </div>
                                    </li>
                                    <li>
                                       <a href="regional-science-city-lucknow.html" target="_blank"><img src="images/regional-science-city-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="regional-science-city-lucknow.html" target="_blank">
                                             <h3>Regional Science City</h3>
                                          </a>
                                       </div>
                                    </li> 
                                 </ul>
                              </div>"""

# %%
#response = requests.get(museums)
soup = BeautifulSoup(museums, 'html.parser')

museum_links = []
for tag in soup.find_all('a', attrs = {'href': True}):
    museum_links.append(tag['href'])
    museum_links = list(set(museum_links))
common_url = 'https://www.tourmyindia.com/states/uttarpradesh/'   
    
museum_links = [common_url +i for i in museum_links]   
    
for i in museum_links:
    response = requests.get(i)
    if response.status_code == 200:
        museum_soup = BeautifulSoup(response.content,'html.parser')
        for tag in museum_soup.find_all('div', attrs={'class':'ab show1'}):
            h1_element = museum_soup.find('h1')
            heading = h1_element.get_text()
            # text = heading.get_text(strip = True)
            with open('Museums.txt', 'a', encoding = 'utf-8') as f:
                
                f.write("Heading" +":-"+ heading)
                f.write(tag.text)

# %%
church= '''<div class="wild-life-tour">
                                 <h2>Churches in Lucknow</h2>
                                 <ul>
                                    <li>
                                       <a href="lalbagh-methodist-church-lucknow.html" target="_blank"><img src="images/lalbagh-methodist-church-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="lalbagh-methodist-church-lucknow.html" target="_blank">
                                             <h3>Lalbagh Methodist Church</h3>
                                          </a>                                      
                                       </div>
                                    </li>
                                    <li>
                                       <a href="christ-church-lucknow.html" target="_blank"><img src="images/christ-church-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="christ-church-lucknow.html" target="_blank">
                                             <h3>Christ Church</h3>
                                          </a>                                      
                                       </div>
                                    </li>
                                    <li>
                                       <a href="all-saints-garrison-church-lucknow.html" target="_blank"><img src="images/all-saints-garrison-church-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="all-saints-garrison-church-lucknow.html" target="_blank">
                                             <h3>All Saints Garrison Church</h3>
                                          </a>                                      
                                       </div>
                                    </li>
                                    <li>
                                       <a href="st-joseph-cathedral-church-lucknow.html" target="_blank"><img src="images/st-joseph-cathedral-church-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="st-joseph-cathedral-church-lucknow.html" target="_blank">
                                             <h3>St. Joseph's Cathedral Church</h3>
                                          </a>                                      
                                       </div>
                                    </li>
                                    <li>
                                       <a href="assembly-god-church-lucknow.html" target="_blank"><img src="images/assembly-god-church-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="assembly-god-church-lucknow.html" target="_blank">
                                             <h3>Assembly of God's Church</h3>
                                          </a>                                      
                                       </div>
                                    </li>
                                 </ul>
                                 </div>'''

# %%
soup1 = BeautifulSoup(church, 'html.parser')

church_links = []
for tag in soup1.find_all('a', attrs = {'href': True}):
    church_links.append(tag['href'])
    church_links = list(set(church_links))
common_url = 'https://www.tourmyindia.com/states/uttarpradesh/'   
    
church_links = [common_url +i for i in church_links]   
    
for i in church_links:
    response = requests.get(i)
    if response.status_code == 200:
        church_soup = BeautifulSoup(response.content,'html.parser')
        for tag in church_soup.find_all('div', attrs={'class':"jammu-outer"}):

            h1_element = church_soup.find('h1')
            heading = h1_element.get_text()
            # text = heading.get_text(strip = True)
            with open('Church.txt', 'a', encoding = 'utf-8') as f:
                
                f.write("Heading" +":-"+ heading)
                f.write(tag.text)

# %%
parks ='''<div class="wild-life-tour">
                                 <h2>Park in Lucknow</h2>
                                 <ul>
                                    <li>
                                       <a href="lucknow-zoo.html" target="_blank"><img src="images/lucknow-zoo1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="lucknow-zoo.html" target="_blank">
                                             <h3>Nawab Wajid Ali Shah Zoological Garden</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="ram-manohar-lohia-park-lucknow.html" target="_blank"><img src="images/ram-manohar-lohia-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="ram-manohar-lohia-park-lucknow.html" target="_blank">
                                             <h3>Dr. Ram Mahohar Lohia Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="kukrail-reserve-forest-lucknow.html" target="_blank"><img src="images/kukrail-reserve-forest-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="kukrail-reserve-forest-lucknow.html" target="_blank">
                                             <h3>Kukrail Reserve Forest</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="begum-hazrat-mahal-park-lucknow.html" target="_blank"><img src="images/begum-hazrat-mahal-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="begum-hazrat-mahal-park-lucknow.html" target="_blank">
                                             <h3>Begum Hazrat Mahal Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="globe-park-lucknow.html" target="_blank"><img src="images/globe-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="globe-park-lucknow.html" target="_blank">
                                             <h3>Globe Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="hathi-park-lucknow.html" target="_blank"><img src="images/hathi-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="hathi-park-lucknow.html" target="_blank">
                                             <h3>Hathi Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="nimbu-park-lucknow.html" target="_blank"><img src="images/nimbu-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="nimbu-park-lucknow.html" target="_blank">
                                             <h3>Neebu Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="gautam-buddha-park-lucknow.html" target="_blank"><img src="images/gautam-buddha-park-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="gautam-buddha-park-lucknow.html" target="_blank">
                                             <h3>Gautam Buddha Park</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="shaheed-smarak-lucknow.html" target="_blank"><img src="images/shaheed-smarak-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="shaheed-smarak-lucknow.html" target="_blank">
                                             <h3>Shaheed Smarak</h3>
                                          </a>                                        
                                       </div>
                                    </li>
                                    <li>
                                       <a href="nbri-lucknow.html" target="_blank"><img src="images/nbri-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="nbri-lucknow.html" target="_blank">
                                             <h3>National Botanical Research Institute</h3>
                                          </a>
                                       </div>
                                    </li>
                                    <li>
                                       <a href="kala-gaon-lucknow.html" target="_blank"><img src="images/kala-gaon-lucknow1.jpg" alt=""></a>
                                       <div class="rajsthan-important-hover1">
                                          <a href="kala-gaon-lucknow.html" target="_blank">
                                             <h3>Kala Gaon</h3>
                                          </a>
                                       </div>
                                    </li>
                                 </ul>
                              </div>'''

# %%
soup2 = BeautifulSoup(parks, 'html.parser')

parks_links = []
for tag in soup1.find_all('a', attrs = {'href': True}):
    parks_links.append(tag['href'])
    parks_links = list(set(parks_links))
common_url = 'https://www.tourmyindia.com/states/uttarpradesh/'   
    
parks_links = [common_url +i for i in parks_links]   
    
for i in parks_links:
    response = requests.get(i)
    if response.status_code == 200:
        parks_soup = BeautifulSoup(response.content,'html.parser')
        for tag in parks_soup.find_all('div', attrs={'class':"jammu-outer"}):

            h1_element = parks_soup.find('h1')
            heading = h1_element.get_text()
            # text = heading.get_text(strip = True)
            with open('Parks.txt', 'a', encoding = 'utf-8') as f:
                
                f.write("Heading" +":-"+ heading)
                f.write(tag.text)
